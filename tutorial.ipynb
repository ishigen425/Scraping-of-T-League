# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib

# %%
player_data = pd.read_csv('./data/player_stats_table_2019.csv')
#名前をイニシャルに変更
for idx, item in player_data.iterrows():
    name = item['player_name']
    split_name = name.split()
    player_data.loc[idx, 'player_name'] = split_name[0][0] + "." + split_name[1]

# player_data = player_data[player_data["match_number"] > 2]
player_data
# Out:
#     season   player_name                 team_name  match_number  \
# 0     2019    H.Yingchao    kinoshitameister-tokyo             7
# 1     2019     J.SaeHyuk            ryukyu-asteeda             5
# 2     2019  K.Matsudaira                tt-saitama             4
# 3     2019   L.Pitchford                tt-saitama             4
# 4     2019    M.Morizono            okayama-rivets             5
# 5     2019         T.Jin                tt-saitama             5
# 6     2019    J.Mizutani    kinoshitameister-tokyo             5
# 7     2019        K.Niwa    kinoshitameister-tokyo             3
# 8     2019     M.Yoshida            okayama-rivets             4
# 9     2019      Y.Hirano                tt-saitama             1
# 10    2019       H.Tazoe    kinoshitameister-tokyo             1
# 11    2019   Y.Muramatsu            ryukyu-asteeda             1
# 12    2019    T.Harimoto    kinoshitameister-tokyo             2
# 13    2019        C.Chih            ryukyu-asteeda             2
# 14    2019         L.Yun            okayama-rivets             3
# 15    2019    W.Chunting                tt-saitama             3
# 16    2019       A.Machi            okayama-rivets             4
# 17    2019        J.Ueda            okayama-rivets             4
# 18    2019   M.Yoshimura            ryukyu-asteeda             1
# 19    2019    Y.Kizukuri            ryukyu-asteeda             1
# 20    2019      M.Takami                tt-saitama             1
# 21    2019   Y.Matsuyama                tt-saitama             1
# 22    2019   K.Yoshimura            okayama-rivets             2
# 23    2019      Y.Oshima    kinoshitameister-tokyo             2
# 24    2019     C.ChienAn            ryukyu-asteeda             3
# 25    2019    Y.Hamamoto  kinoshitaabyell-kanagawa             6
# 26    2019   S.Suthasini       nipponpaint-mallets             6
# 27    2019    K.Ishikawa  kinoshitaabyell-kanagawa             8
# 28    2019        M.Kato       nipponpaint-mallets            10
# 29    2019      H.Hayata             nissay-redelf             8
# 30    2019       J.Jihee             nissay-redelf             4
# 31    2019      A.Morita                top-nagoya             7
# 32    2019       C.SzuYu             nissay-redelf             2
# 33    2019      Y.Mengyu             nissay-redelf             2
# 34    2019      C.IChing                top-nagoya             4
# 35    2019         D.Hoi  kinoshitaabyell-kanagawa             4
# 36    2019        S.Mori             nissay-redelf             5
# 37    2019        H.Ying                top-nagoya             1
# 38    2019     L.HoChing       nipponpaint-mallets             1
# 39    2019       A.Sasao                top-nagoya             2
# 40    2019        Z.Jian  kinoshitaabyell-kanagawa             4
# 41    2019       M.Maeda             nissay-redelf             1
# 42    2019      M.Kihara  kinoshitaabyell-kanagawa             1
# 43    2019     Y.Umemura                top-nagoya             1
# 44    2019         S.Wai       nipponpaint-mallets             2
# 45    2019    S.Yamamoto                top-nagoya             2
# 46    2019        Y.Soma       nipponpaint-mallets             3
# 47    2019       Y.HAEUN                top-nagoya             4
#
#     VM_match_number  win_match  lose_match  win_game  lose_game shut_out_rate  \
# 0                 1          5           2        17          8           29%
# 1                 1          4           1        12          6           20%
# 2                 0          3           1        10          9            0%
# 3                 0          3           1         9          5           50%
# 4                 0          3           2        11          8           40%
# 5                 1          3           2         9          9            0%
# 6                 1          3           2         8          6           40%
# 7                 0          2           1         8          5           33%
# 8                 1          2           2         5          6           25%
# 9                 0          1           0         3          1            0%
# 10                0          1           0         3          1            0%
# 11                0          1           0         3          2            0%
# 12                0          1           1         5          3           50%
# 13                0          1           1         4          5            0%
# 14                1          1           2         5          4           33%
# 15                0          1           2         5          8            0%
# 16                0          1           3         5         10            0%
# 17                2          1           3         3          6            0%
# 18                0          0           1         2          3            0%
# 19                0          0           1         1          3            0%
# 20                0          0           1         1          3            0%
# 21                0          0           1         0          3            0%
# 22                0          0           2         2          6            0%
# 23                0          0           2         2          6            0%
# 24                0          0           3         2          9            0%
# 25                1          5           1        15          6           33%
# 26                0          5           1        15          8           33%
# 27                3          5           3        15          8           13%
# 28                4          5           5        15         13           20%
# 29                3          4           4        14         12            0%
# 30                1          3           1         9          6            0%
# 31                1          3           4         9         16            0%
# 32                0          2           0         6          3            0%
# 33                0          2           0         6          4            0%
# 34                1          2           2         8          8            0%
# 35                1          2           2         7          7            0%
# 36                0          2           3         8         11           20%
# 37                0          1           0         3          1            0%
# 38                0          1           0         3          2            0%
# 39                0          1           1         4          3           50%
# 40                0          1           3         9          9           25%
# 41                0          0           1         1          3            0%
# 42                0          0           1         1          3            0%
# 43                0          0           1         0          3            0%
# 44                0          0           2         4          6            0%
# 45                0          0           2         1          6            0%
# 46                0          0           3         2          9            0%
# 47                1          0           4         2         10            0%
#
#                ...               rally_count_at_win_6  rally_count_at_win_8  \
# 0              ...                                 20                    11
# 1              ...                                 15                     6
# 2              ...                                 12                     6
# 3              ...                                 16                     1
# 4              ...                                 10                     4
# 5              ...                                  8                     4
# 6              ...                                 12                     8
# 7              ...                                  2                     6
# 8              ...                                  4                     4
# 9              ...                                  2                     3
# 10             ...                                  3                     0
# 11             ...                                  5                     3
# 12             ...                                  4                     0
# 13             ...                                  6                     3
# 14             ...                                  5                     0
# 15             ...                                  5                     5
# 16             ...                                  5                     9
# 17             ...                                  4                     0
# 18             ...                                  5                     1
# 19             ...                                  2                     0
# 20             ...                                  0                     1
# 21             ...                                  2                     0
# 22             ...                                  7                     1
# 23             ...                                  5                     2
# 24             ...                                  5                     1
# 25             ...                                 10                     9
# 26             ...                                 12                     3
# 27             ...                                  9                     5
# 28             ...                                 15                    10
# 29             ...                                  7                     7
# 30             ...                                  3                     3
# 31             ...                                 15                     3
# 32             ...                                  6                     1
# 33             ...                                  5                     3
# 34             ...                                 13                     2
# 35             ...                                  8                     7
# 36             ...                                 11                     8
# 37             ...                                  2                     3
# 38             ...                                  0                     0
# 39             ...                                  4                     1
# 40             ...                                 10                     7
# 41             ...                                  2                     0
# 42             ...                                  0                     0
# 43             ...                                  1                     0
# 44             ...                                  2                     1
# 45             ...                                  5                     0
# 46             ...                                  4                     4
# 47             ...                                  3                     3
#
#     rally_count_at_win_10 rally_count_at_win_over_12  rally_count_at_lose_2  \
# 0                       9                          0                     14
# 1                       3                          0                     13
# 2                       4                          0                     21
# 3                       2                          0                     15
# 4                       0                          1                     23
# 5                       3                          3                     23
# 6                       1                          0                      7
# 7                       1                          1                     17
# 8                       1                          0                     16
# 9                       0                          0                      6
# 10                      0                          1                      4
# 11                      0                          0                      1
# 12                      1                          0                     13
# 13                      1                          1                      8
# 14                      1                          0                     16
# 15                      1                          2                     14
# 16                      2                          0                     24
# 17                      1                          0                     19
# 18                      0                          0                      4
# 19                      0                          0                      4
# 20                      1                          1                      3
# 21                      0                          1                      6
# 22                      1                          0                     10
# 23                      0                          0                     12
# 24                      0                          0                      8
# 25                      1                          0                     31
# 26                      1                          1                     20
# 27                      1                          1                     37
# 28                      4                          0                     18
# 29                      0                          0                     38
# 30                      2                          3                     20
# 31                      0                          0                     36
# 32                      2                          6                      9
# 33                      0                          0                     13
# 34                      1                          1                     26
# 35                      3                          1                     19
# 36                      2                          0                     17
# 37                      1                          0                      2
# 38                      0                          0                      5
# 39                      0                          3                      9
# 40                      2                          1                     12
# 41                      1                          0                      4
# 42                      0                          0                      9
# 43                      0                          0                     10
# 44                      1                          0                     15
# 45                      0                          0                     12
# 46                      1                          0                      6
# 47                      1                          2                     15
#
#     rally_count_at_lose_4  rally_count_at_lose_6  rally_count_at_lose_8  \
# 0                      30                     17                     18
# 1                      28                     17                      6
# 2                      25                     22                      8
# 3                      30                      7                      6
# 4                      29                     18                      4
# 5                      42                     13                      7
# 6                      18                     16                      7
# 7                      34                      8                      3
# 8                      21                      8                      3
# 9                       3                      2                      2
# 10                      6                      5                      0
# 11                      4                      6                      9
# 12                     15                      5                      2
# 13                     16                      8                      0
# 14                     16                      2                      3
# 15                     25                     12                      7
# 16                     27                     14                      6
# 17                     22                      3                      1
# 18                     12                      4                      1
# 19                     15                      1                      1
# 20                      8                      3                      3
# 21                      4                      3                      4
# 22                     15                      5                      5
# 23                     17                      6                      1
# 24                     30                     15                      2
# 25                     32                     14                      6
# 26                     51                     18                      7
# 27                     36                     18                      3
# 28                     43                     30                     15
# 29                     46                     23                      3
# 30                     29                     11                      9
# 31                     55                     13                     11
# 32                     17                      6                      3
# 33                     25                     10                      4
# 34                     25                      7                      7
# 35                     27                     15                      4
# 36                     39                     17                      7
# 37                      4                      2                      0
# 38                      7                      4                      1
# 39                      8                     10                      1
# 40                     37                     18                      9
# 41                      7                      4                      1
# 42                      8                      3                      1
# 43                      5                      2                      1
# 44                     16                     12                      4
# 45                     18                      6                      2
# 46                     19                     11                      9
# 47                     27                     12                      7
#
#     rally_count_at_lose_10  rally_count_at_lose_over_12
# 0                        9                            8
# 1                        1                            8
# 2                        0                            5
# 3                        1                            0
# 4                        0                            0
# 5                        2                            0
# 6                        2                            5
# 7                        2                            0
# 8                        3                            0
# 9                        1                            0
# 10                       0                            0
# 11                       2                            4
# 12                       0                            1
# 13                       3                            0
# 14                       1                            1
# 15                       2                            0
# 16                       4                            0
# 17                       1                            0
# 18                       0                            0
# 19                       0                            0
# 20                       2                            0
# 21                       0                            0
# 22                       4                            0
# 23                       0                            0
# 24                       2                            1
# 25                       2                            0
# 26                       2                            0
# 27                       4                            0
# 28                       4                            1
# 29                       3                            1
# 30                       2                            0
# 31                       2                            2
# 32                       3                            0
# 33                       0                            1
# 34                       3                            0
# 35                       4                            0
# 36                       7                            1
# 37                       3                            1
# 38                       0                            0
# 39                       1                            0
# 40                       5                            0
# 41                       0                            1
# 42                       0                            0
# 43                       0                            0
# 44                       2                            2
# 45                       0                            0
# 46                       6                            8
# 47                       1                            0
#
# [48 rows x 64 columns]

# %%
get_points_rate = player_data.loc[:, ["player_name","get_points_rate_on_serve","get_points_rate_on_receive", "team_name"]]
get_points_rate.set_index("player_name", inplace=True)
get_points_rate
# Out:
#               get_points_rate_on_serve  get_points_rate_on_receive  \
# player_name
# H.Yingchao                       0.583                       0.514
# J.SaeHyuk                        0.555                       0.490
# K.Matsudaira                     0.577                       0.462
# L.Pitchford                      0.544                       0.535
# M.Morizono                       0.494                       0.537
# T.Jin                            0.565                       0.422
# J.Mizutani                       0.563                       0.520
# K.Niwa                           0.580                       0.423
# M.Yoshida                        0.462                       0.490
# Y.Hirano                         0.568                       0.600
# H.Tazoe                          0.571                       0.543
# Y.Muramatsu                      0.605                       0.386
# T.Harimoto                       0.614                       0.471
# C.Chih                           0.442                       0.532
# L.Yun                            0.649                       0.466
# W.Chunting                       0.518                       0.446
# A.Machi                          0.493                       0.416
# J.Ueda                           0.464                       0.440
# M.Yoshimura                      0.500                       0.523
# Y.Kizukuri                       0.450                       0.462
# M.Takami                         0.457                       0.429
# Y.Matsuyama                      0.333                       0.261
# K.Yoshimura                      0.403                       0.426
# Y.Oshima                         0.358                       0.455
# C.ChienAn                        0.495                       0.410
# Y.Hamamoto                       0.565                       0.500
# S.Suthasini                      0.547                       0.503
# K.Ishikawa                       0.586                       0.492
# M.Kato                           0.510                       0.504
# H.Hayata                         0.581                       0.493
# J.Jihee                          0.617                       0.462
# A.Morita                         0.514                       0.436
# C.SzuYu                          0.618                       0.481
# Y.Mengyu                         0.589                       0.418
# C.IChing                         0.551                       0.465
# D.Hoi                            0.512                       0.416
# S.Mori                           0.503                       0.444
# H.Ying                           0.583                       0.583
# L.HoChing                        0.556                       0.528
# A.Sasao                          0.547                       0.516
# Z.Jian                           0.536                       0.478
# M.Maeda                          0.447                       0.528
# M.Kihara                         0.438                       0.364
# Y.Umemura                        0.400                       0.280
# S.Wai                            0.530                       0.393
# S.Yamamoto                       0.424                       0.441
# Y.Soma                           0.475                       0.354
# Y.HAEUN                          0.440                       0.404
#
#                              team_name
# player_name
# H.Yingchao      kinoshitameister-tokyo
# J.SaeHyuk               ryukyu-asteeda
# K.Matsudaira                tt-saitama
# L.Pitchford                 tt-saitama
# M.Morizono              okayama-rivets
# T.Jin                       tt-saitama
# J.Mizutani      kinoshitameister-tokyo
# K.Niwa          kinoshitameister-tokyo
# M.Yoshida               okayama-rivets
# Y.Hirano                    tt-saitama
# H.Tazoe         kinoshitameister-tokyo
# Y.Muramatsu             ryukyu-asteeda
# T.Harimoto      kinoshitameister-tokyo
# C.Chih                  ryukyu-asteeda
# L.Yun                   okayama-rivets
# W.Chunting                  tt-saitama
# A.Machi                 okayama-rivets
# J.Ueda                  okayama-rivets
# M.Yoshimura             ryukyu-asteeda
# Y.Kizukuri              ryukyu-asteeda
# M.Takami                    tt-saitama
# Y.Matsuyama                 tt-saitama
# K.Yoshimura             okayama-rivets
# Y.Oshima        kinoshitameister-tokyo
# C.ChienAn               ryukyu-asteeda
# Y.Hamamoto    kinoshitaabyell-kanagawa
# S.Suthasini        nipponpaint-mallets
# K.Ishikawa    kinoshitaabyell-kanagawa
# M.Kato             nipponpaint-mallets
# H.Hayata                 nissay-redelf
# J.Jihee                  nissay-redelf
# A.Morita                    top-nagoya
# C.SzuYu                  nissay-redelf
# Y.Mengyu                 nissay-redelf
# C.IChing                    top-nagoya
# D.Hoi         kinoshitaabyell-kanagawa
# S.Mori                   nissay-redelf
# H.Ying                      top-nagoya
# L.HoChing          nipponpaint-mallets
# A.Sasao                     top-nagoya
# Z.Jian        kinoshitaabyell-kanagawa
# M.Maeda                  nissay-redelf
# M.Kihara      kinoshitaabyell-kanagawa
# Y.Umemura                   top-nagoya
# S.Wai              nipponpaint-mallets
# S.Yamamoto                  top-nagoya
# Y.Soma             nipponpaint-mallets
# Y.HAEUN                     top-nagoya

# %%
# 男子
man_get_points_rate = get_points_rate[(get_points_rate['team_name'] == 'tt-saitama')
     | (get_points_rate['team_name'] == 'kinoshitameister-tokyo')
     | (get_points_rate['team_name'] == 'okayama-rivets')
     | (get_points_rate['team_name'] == 'ryukyu-asteeda')]

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(man_get_points_rate['get_points_rate_on_serve'], man_get_points_rate['get_points_rate_on_receive'],
                    marker="o",alpha=0.5,c='blue')
for k, v in man_get_points_rate.iterrows():
            ax.annotate(v.name, xy=(v['get_points_rate_on_serve'],v['get_points_rate_on_receive']), size=10, alpha=0.5)
plt.title('サーブ・レシーブ別得点率(男子)')
ax.set_xlabel('サーブ時得点率')
ax.set_ylabel('レシーブ時得点率')
fig.show()
plt.savefig("./data/man_get_points_rate")

# %%
#女子
woman_get_points_rate = get_points_rate[(get_points_rate['team_name'] == 'top-nagoya')
     | (get_points_rate['team_name'] == 'nissay-redelf')
     | (get_points_rate['team_name'] == 'nipponpaint-mallets')
     | (get_points_rate['team_name'] == 'rkinoshitaabyell-kanagawa')]
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(woman_get_points_rate['get_points_rate_on_serve'], woman_get_points_rate['get_points_rate_on_receive'],
                    marker="o",alpha=0.5,c='red')
for k, v in woman_get_points_rate.iterrows():
            ax.annotate(v.name, xy=(v['get_points_rate_on_serve'],v['get_points_rate_on_receive']), size=10, alpha=0.5)
plt.title('サーブ・レシーブ別得点率(女子)')
ax.set_xlabel('サーブ時得点率')
ax.set_ylabel('レシーブ時得点率')
fig.show()
